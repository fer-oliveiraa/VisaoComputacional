# %% [markdown]
# <a href="https://colab.research.google.com/github/fer-oliveiraa/VisaoComputacional/blob/main/Detec%C3%A7%C3%A3o_de_objetos_com_Python%2C_OpenCV_e_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bibliotecas**

# %%
# !pip install ultralytics==8.0.0 -q

# %%
from IPython.display import Image
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # **Imagem e vídeo de exemplo**

# %%
# !gdown "https://drive.google.com/file/d/159WC6qLiJWl__HndwjBskTj-czTRk43T/view?usp=drive_link"
# !gdown "https://drive.google.com/file/d/10kCJTvLCKQBpRjofCLYm0rMnjGB3Nzzi/view?usp=drive_link"
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=159WC6qLiJWl__HndwjBskTj-czTRk43T
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/159WC6qLiJWl__HndwjBskTj-czTRk43T/view?usp=drive_link
# To: /content/view?usp=drive_link
# 8.93kB [00:00, 23.4MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=10kCJTvLCKQBpRjofCLYm0rMnjGB3Nzzi
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/10kCJTvLCKQBpRjofCLYm0rMnjGB3Nzzi/view?usp=drive_link
# To: /content/view?usp=drive_link
# 8.93kB [00:00, 20.1MB/s]

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/pisa.png'
# Out:
# 2025-01-28 17:58:20.039668: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-28 17:58:20.058742: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-28 17:58:20.064833: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-28 17:58:20.078771: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# O resultado será armazenado na pasta "runs/detect/predict/nome_do_arquivo"

# %%
Image('/content/runs/detect/predict/pisa.png', width=500)

# %% [markdown]
# # **Detecção de Objetos em Vídeos**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/rodovia.mp4'
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# video 1/1 (13062/18059) /content/rodovia.mp4: 384x640 1 person, 15 cars, 10.2ms
# video 1/1 (13063/18059) /content/rodovia.mp4: 384x640 1 person, 15 cars, 1 truck, 10.2ms
# video 1/1 (13064/18059) /content/rodovia.mp4: 384x640 1 person, 12 cars, 1 truck, 10.2ms
# video 1/1 (13065/18059) /content/rodovia.mp4: 384x640 13 cars, 1 truck, 10.2ms
# video 1/1 (13066/18059) /content/rodovia.mp4: 384x640 1 person, 15 cars, 1 truck, 10.2ms
# video 1/1 (13067/18059) /content/rodovia.mp4: 384x640 1 person, 15 cars, 1 truck, 10.2ms
# video 1/1 (13068/18059) /content/rodovia.mp4: 384x640 1 person, 14 cars, 1 bus, 10.2ms
# video 1/1 (13069/18059) /content/rodovia.mp4: 384x640 1 person, 15 cars, 10.2ms
# video 1/1 (13070/18059) /content/rodovia.mp4: 384x640 2 persons, 16 cars, 10.2ms
# video 1/1 (13071/18059) /content/rodovia.mp4: 384x640 1 person, 17 cars, 10.2ms
# ...

# %% [markdown]
# Agora para exibir o vídeo

# %%
from IPython.display import HTML
from base64 import b64encode
import os

save_path = '/content/runs/detect/predict2/rodovia.mp4'

compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")


mp4 = open(compressed_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
        <source src="%s" type="video/mp4">
        </video>
        """ % data_url)
# Out:
# Buffered data was truncated after reaching the output size limit.
